# %% [markdown]
# # Shoe Brand Classification Project
# ## COMP S492F / COMP3920SEF Machine Learning
#
# **Student:** Ashwin-Sundar[13139477], Maria[To be completed]
# **Tutorial Session:** P21
# **Date:** April 2026

# %%
# ============================================
# 1. LIBRARY IMPORTS
# ============================================

# TensorFlow - Deep Learning Framework
# Contains everything for neural networks: layers, optimizers, data loading
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import MobileNetV2  # Transfer learning base

# NumPy - Numerical Python
# Works with arrays (images are just 3D arrays of numbers!)
import numpy as np

# Pathlib - File Path Handling
# Makes working with file paths cross-platform (Windows/Mac/Linux)
import pathlib

# Matplotlib - Plotting Library
# Creates graphs and visualizations
import matplotlib.pyplot as plt

# scikit-learn - Machine Learning Utilities
# Provides metrics for evaluating our model
from sklearn.metrics import classification_report, confusion_matrix

# Seaborn - Statistical Data Visualization
# Makes prettier heatmaps for confusion matrices
import seaborn as sns

# Set random seeds for reproducibility
# This ensures we get the same results each run
tf.random.set_seed(42)
np.random.seed(42)

# Check setup
print("=" * 50)
print("ENVIRONMENT SETUP CHECK")
print("=" * 50)
print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
print(f"GPU Available: {len(tf.config.list_physical_devices('GPU')) > 0}")
print("=" * 50)
